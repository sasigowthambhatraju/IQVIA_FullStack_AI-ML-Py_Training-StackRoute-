# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# As U can see from above code there are missing values in above ds
# So for childern there are 4 missing values here we'll be replacing with mean or median
# for agent the dtype is float so we can use either mean or median
# but for country it's dtype is object so we need to use mode only in order to replace the null values in the column
# As the company column is having so much nan values out of overall data we can remove the colun entirely becoz it's not impacting

# %%
mean_childern = df['children'].mean()
mean_childern
# Out:
# 0.10388990333874994

# %%
# Now replacing the null values from childern column in the ds
df['children'].replace(np.nan, mean_childern, inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# For agent i.e of float dtype
median_agent = df['agent'].median()
median_agent
# Out:
# 14.0

# %%
df['agent'].replace(np.nan, median_agent, inplace=True)

# %%
# As U can see from above lines of code the childern's column null values got replaced now it's for country column
# because it's object type we'll be using mode

country_mode = df['country'].mode().values[0]
country_mode
# Out:
# 'PRT'

# %%
df['country'].replace(np.nan, country_mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Checking for duplicates
duplicate = df.duplicated()
duplicate.sum()
# Out:
# 32013

# %%
df[duplicate]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
# Now from above we'r going 2drop the duplicate data from the ds
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (87377, 32)

# %%
# AS U can see that the rows count have been reduced from 119390 to 87377

# %%
# Because the company column is having so much missing data we can remove the company column becoz it's not going to impact
df.drop("company", axis=1, inplace=True)

# %%
df.shape # as u can see that 1column is removed
# Out:
# (87377, 31)

# %%
# Checking and removing the outliers using boxplot
df.boxplot(column='lead_time')
# Out:
# <AxesSubplot:>

# %%
# Function for removing the outliers from 1column
def remove_outliers(col):
    sorted(col)
    q1, q3 = col.quantile([0.25,0.75])
    iqr = q3-q1
    lower_range = q1-(1.5*iqr)
    upper_range = q3+(1.5*iqr)
    return lower_range, upper_range

# %%
lowledtime, uppleadtime = remove_outliers(df['lead_time'])

# %%
df['lead_time'] = np.where(df['lead_time']>uppleadtime, uppleadtime, df['lead_time'])

# %%
df['lead_time'] = np.where(df['lead_time']<lowledtime, lowledtime, df['lead_time'])

# %%
df.boxplot(column='lead_time')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df['lead_time'] = sc.fit_transform(df[['lead_time']])
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0   2.685052               2015               July
# 1  Resort Hotel            0   2.685052               2015               July
# 2  Resort Hotel            0  -0.880675               2015               July
# 3  Resort Hotel            0  -0.806646               2015               July
# 4  Resort Hotel            0  -0.794308               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                         float64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# One-hot encoding for conversion of categorical object type into numerical data
df2 = pd.get_dummies(df, columns=["arrival_date_year","meal","country","market_segment", "distribution_channel", "reserved_room_type", "assigned_room_type","reservation_status_date","hotel", "arrival_date_month", "deposit_type", "customer_type", "reservation_status"])
df2
# Out:
#         is_canceled  lead_time  arrival_date_week_number  \
# 0                 0   2.685052                        27
# 1                 0   2.685052                        27
# 2                 0  -0.880675                        27
# 3                 0  -0.806646                        27
# 4                 0  -0.794308                        27
# ...             ...        ...                       ...
# 119385            0  -0.683264                        35
# 119386            0   0.291450                        35
# 119387            0  -0.547544                        35
# 119388            0   0.377817                        35
# 119389            0   1.562280                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# ...

# %%
df2.dtypes
# Out:
# is_canceled                        int64
# lead_time                        float64
# arrival_date_week_number           int64
# arrival_date_day_of_month          int64
# stays_in_weekend_nights            int64
#                                   ...
# customer_type_Transient            uint8
# customer_type_Transient-Party      uint8
# reservation_status_Canceled        uint8
# reservation_status_Check-Out       uint8
# reservation_status_No-Show         uint8
# Length: 1188, dtype: object

# %%
df['is_canceled'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(x ='is_canceled', data=df)
# Out:
# <AxesSubplot:xlabel='is_canceled', ylabel='count'>

# %%
df.hist(figsize=(10,20))
# Out:
# array([[<AxesSubplot:title={'center':'is_canceled'}>,
#         <AxesSubplot:title={'center':'lead_time'}>,
#         <AxesSubplot:title={'center':'arrival_date_year'}>,
#         <AxesSubplot:title={'center':'arrival_date_week_number'}>],
#        [<AxesSubplot:title={'center':'arrival_date_day_of_month'}>,
#         <AxesSubplot:title={'center':'stays_in_weekend_nights'}>,
#         <AxesSubplot:title={'center':'stays_in_week_nights'}>,
#         <AxesSubplot:title={'center':'adults'}>],
#        [<AxesSubplot:title={'center':'children'}>,
#         <AxesSubplot:title={'center':'babies'}>,
#         <AxesSubplot:title={'center':'is_repeated_guest'}>,
#         <AxesSubplot:title={'center':'previous_cancellations'}>],
#        [<AxesSubplot:title={'center':'previous_bookings_not_canceled'}>,
#         <AxesSubplot:title={'center':'booking_changes'}>,
#         <AxesSubplot:title={'center':'agent'}>,
#         <AxesSubplot:title={'center':'days_in_waiting_list'}>],
# ...

# %%
sns.pairplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-4b9ab8d39ae3> in <module>
# ----> 1 sns.pairplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() missing 1 required positional argument: 'data'

# %%
corr = df.corr()
corr

# %%
# sns.heatmap(corr, annot=True, cmap='YlGnBu')
